# %% [markdown]
# <a href="https://colab.research.google.com/github/a3d2ddk/Prenith-and-Drew-Project-Deep-Dive/blob/main/build_pytorch3d_wheel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facebookresearch/pytorch3d.git
# Out:
# Cloning into 'pytorch3d'...
# remote: Enumerating objects: 15121, done.
# remote: Counting objects: 100% (2695/2695), done.
# remote: Compressing objects: 100% (377/377), done.
# remote: Total 15121 (delta 2432), reused 2326 (delta 2318), pack-reused 12426 (from 1)
# Receiving objects: 100% (15121/15121), 49.41 MiB | 28.02 MiB/s, done.
# Resolving deltas: 100% (10613/10613), done.

# %%
#!pip install build wheel torch torchvision
# %cd pytorch3d
# !python setup.py bdist_wheel
# Out:
# ...
# /content/pytorch3d
# W1018 21:47:57.074000 1343 torch/utils/cpp_extension.py:118] No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running bdist_wheel
# W1018 21:47:57.522000 1343 torch/utils/cpp_extension.py:615] Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
# running build
# running build_py
# creating build/lib.linux-x86_64-cpython-312/projects
# copying projects/__init__.py -> build/lib.linux-x86_64-cpython-312/projects
# creating build/lib.linux-x86_64-cpython-312/pytorch3d
# copying pytorch3d/__init__.py -> build/lib.linux-x86_64-cpython-312/pytorch3d
# creating build/lib.linux-x86_64-cpython-312/pytorch3d/datasets
# copying pytorch3d/datasets/utils.py -> build/lib.linux-x86_64-cpython-312/pytorch3d/datasets
# copying pytorch3d/datasets/__init__.py -> build/lib.linux-x86_64-cpython-312/pytorch3d/datasets
# ...

# %%
import glob, os
wheels = glob.glob("dist/*.whl")
print("📦 Built wheels:", wheels)
# Out:
# 📦 Built wheels: ['dist/pytorch3d-0.7.8-cp312-cp312-linux_x86_64.whl']

# %%
from google.colab import drive
drive.mount('/content/drive')
save_path = "/content/drive/MyDrive/pytorch3d_wheels/"
os.makedirs(save_path, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for w in wheels:
    # !cp $w $save_path
print("✅ Wheel(s) saved to:", save_path)
# Out:
# ✅ Wheel(s) saved to: /content/drive/MyDrive/pytorch3d_wheels/
